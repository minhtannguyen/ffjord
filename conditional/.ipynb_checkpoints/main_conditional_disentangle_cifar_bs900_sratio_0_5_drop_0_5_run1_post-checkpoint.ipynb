# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='4,5,6,7'

# %%
# %run -p ../train_cnf_disentangle_cifar.py --data cifar10 --dims 64,64,64 --strides 1,1,1,1 --num_blocks 2 --layer_type concat --multiscale True --rademacher True --batch_size 900 --test_batch_size 500 --save ../experiments_published/cnf_conditional_disentangle_cifar10_bs900_sratio_0_5_drop_0_5_run1_post --load_dir ../experiments_published/cnf_conditional_disentangle_cifar10_bs900_sratio_0_5_drop_0_5_run1 --seed 1 --resume_load 113 --lr 0.001 --conditional True --controlled_tol False --train_mode semisup --log_freq 10 --weight_y 0.5 --condition_ratio 0.5 --dropout_rate 0.5
#
# Out:
# usage: Continuous Normalizing Flow [-h]
#                                    [--data {mnist,svhn,cifar10,lsun_church}]
#                                    [--dims DIMS] [--strides STRIDES]
#                                    [--num_blocks NUM_BLOCKS]
#                                    [--conv {True,False}]
#                                    [--layer_type {ignore,concat,concat_v2,squash,concatsquash,concatcoord,hyper,blend}]
#                                    [--divergence_fn {brute_force,approximate}]
#                                    [--nonlinearity {tanh,relu,softplus,elu,swish}]
#                                    [--seed SEED]
#                                    [--solver {dopri5,bdf,rk4,midpoint,adams,explicit_adams}]
#                                    [--atol ATOL] [--rtol RTOL]
#                                    [--step_size STEP_SIZE]
#                                    [--test_solver {dopri5,bdf,rk4,midpoint,adams,explicit_adams,None}]
# ...
