# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0,1,2,3,4,5'

# %%
# %run -p ../train_cnf_generative.py --data mnist --dims 64,64,64 --strides 1,1,1,1 --num_blocks 2 --layer_type concat --multiscale True --rademacher True --batch_size 900 --test_batch_size 500 --save ../experiments/cnf_conditional_generative_bs900_sratio_0_5_drop_0_5_seed_1 --seed 1 --conditional True --controlled_tol False --train_mode semisup --log_freq 10 --weight_y 0.5 --condition_ratio 0.5 --dropout_rate 0.5
# Out:
# /tancode/repos/tan-ffjord/train_cnf_generative.py
# Iter 0010 | Time 13.1061(31.9464) | Bit/dim 17.8126(19.1350) | Xent 28.7920(30.0391) | Loss 32.2086(34.1545) | Error 0.5711(0.8207) Steps 410(410.00) | Grad Norm 206.9115(224.9842) | Total Time 10.00(10.00)
# Iter 0020 | Time 12.7212(26.9098) | Bit/dim 14.6369(18.3148) | Xent 25.2664(29.2004) | Loss 27.2701(32.9150) | Error 0.6467(0.7607) Steps 410(410.00) | Grad Norm 149.4440(212.0507) | Total Time 10.00(10.00)
# Iter 0030 | Time 12.7575(23.2028) | Bit/dim 11.9651(16.9412) | Xent 21.5235(27.6000) | Loss 22.7268(30.7412) | Error 0.4022(0.6972) Steps 410(410.00) | Grad Norm 81.6629(184.9775) | Total Time 10.00(10.00)
# Iter 0040 | Time 12.8845(20.4812) | Bit/dim 10.2983(15.3723) | Xent 19.1660(25.6131) | Loss 19.8813(28.1788) | Error 0.3522(0.6081) Steps 410(410.00) | Grad Norm 33.1688(149.7588) | Total Time 10.00(10.00)
# ...
