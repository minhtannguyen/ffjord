# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='4,5,6,7'

# %%
# %run -p ../train_cnf_disentangle_rl.py --data cifar10 --dims 64,64,64 --strides 1,1,1,1 --num_blocks 2 --layer_type concat --multiscale True --rademacher True --batch_size 900 --test_batch_size 500 --save ../experiments_published/cnf_cifar10_bs900_rl_stdscale_15_run3 --resume ../experiments_published/cnf_cifar10_bs900_rl_stdscale_15_run3/epoch_150_checkpt.pth --seed 3 --lr 0.001 --conditional False --controlled_tol False --log_freq 10 --scale_fac 1.0 --scale_std 15.0
#
# Out:
# /tancode/repos/tan-ffjord/train_cnf_disentangle_rl.py
# import argparse
# import os
# import time
# import numpy as np
#
# import torch
# import torch.optim as optim
# import torchvision.datasets as dset
# import torchvision.transforms as tforms
# from torchvision.utils import save_image
#
# import torch.utils.data as data
# from torch.utils.data import Dataset
#
# import matplotlib.pyplot as plt
# plt.rcParams['figure.dpi'] = 300
#
# from PIL import Image
# import os.path
# import errno
# import codecs
#
# import lib.layers as layers
# import lib.utils as utils
# import lib.multiscale_parallel as multiscale_parallel
# import lib.modules as modules
# import lib.thops as thops
#
# from train_misc import standard_normal_logprob
# from train_misc import set_cnf_options, count_nfe, count_parameters, count_total_time, count_nfe_gate
# from train_misc import add_spectral_norm, spectral_norm_power_iteration
# ...
